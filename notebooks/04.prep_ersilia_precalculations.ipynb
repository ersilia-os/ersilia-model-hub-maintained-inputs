# %%
import os
import pandas as pd

datapath = "../data"

# %%
df = pd.read_csv(os.path.join(datapath, "chembl_standardized.csv"))
df.shape
# Out:
# (1355160, 7)

# %%
df[["standardized_smiles"]].to_csv(os.path.join(datapath, "reference_library_smiles.csv"), index=False)
